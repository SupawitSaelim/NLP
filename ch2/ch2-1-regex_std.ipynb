# %% [markdown]
# **Regex**
#
# What are regular expressions?

# %% [markdown]
# import Regular Expressions Module

# %%
import re

# %% [markdown]
# *   **match**() match an entire string or substring based on a pattern

# %%
re.match("abc","abcdef")
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %% [markdown]
# Pattern?
#
# Pattern "**\w+**"?

# %%
word_regex = "\w+"
re.match(word_regex, "hi there!")
# Out:
# <re.Match object; span=(0, 2), match='hi'>

# %% [markdown]
# **regex** module
# *   **split**() split a string on regex

# %%
text = "Split on spaces!"
re.split('\s+', 'Split on spaces.')
# Out:
# ['Split', 'on', 'spaces.']

# %% [markdown]
# *   **findall**() find all patterns in a string
# *   **search**() search for a pattern
# *   **match**() match an entire string or substring based on a pattern

# %%
word_search = 'spaces!'
print(re.findall(word_search, text))
print(re.search(word_search, text))
print(re.match(word_search, text))
# Out:
# ['spaces!']
# <re.Match object; span=(9, 16), match='spaces!'>
# None

# %% [markdown]
# **Let's practice!!!**

# %% [markdown]
# **Ex.1:**
#
# Which of the following Regex patterns results in the following text?

# %%
PATTERN =
my_string = "Let's write RegEx!"
re.findall(PATTERN, my_string)
# Out:
# ['Let', 's', 'write', 'RegEx']

# %% [markdown]
# **Ex.2:**
#
# re.**split**() and re.**findall**()

# %%
my_string = "Let's write RegEx! Won't that be fun? I sure think so. Can you find 4 sentences? Or perhaps, all 19 words?"

# %% [markdown]
# Write a pattern to match sentence endings: sentence_endings

# %%
sentence_endings =

# %% [markdown]
# Split my_string on sentence endings and print the result

# %%
re.
# Out:
# ["Let's write RegEx",
#  " Won't that be fun",
#  ' I sure think so',
#  ' Can you find 4 sentences',
#  ' Or perhaps, all 19 words',
#  '']

# %% [markdown]
# Find all capitalized words in my_string

# %%
capitalized_words =
re.
# Out:
# ['Let', 'RegEx', 'Won', 'Can', 'Or']

# %% [markdown]
# Split my_string on spaces

# %%
spaces =
re.
# Out:
# ["Let's", 'write', 'RegEx!', "Won't", 'that', 'be', 'fun?', 'I', 'sure', 'think', 'so.', 'Can', 'you', 'find', '4', 'sentences?', 'Or', 'perhaps,', 'all', '19', 'words?']

# %% [markdown]
# Find all digits in my_string and print the result

# %%
digits =
re.
# Out:
# ['4', '19']

# %% [markdown]
# **Work1:**
#
# จงหาว่าในประโยคต่อไปนี้ มี ข้อความ (strings) และ ตัวเลข (numbers) จำนวนเท่าไหร่

# %%
text_work1 = """
John bought 3 apples, 2 bananas, and 5 oranges from the market.
The total cost was $15.75. He visited the market on 05/07/2024.
For any queries, contact him at john.doe@example.com or call at (123) 456-7890.
His order number was 456123789 and was delivered on 10-07-2024.
His friend's email is jane_smith@work-email.co.uk and her phone number is 987-654-3210.
"""

# %% [markdown]
# "**\b**" ใน regular expressions หมายถึง "word boundary" หรือขอบของคำ

# %%
# Out:
# Strings(54):['John', 'bought', 'apples', 'bananas', 'and', 'oranges', 'from', 'the', 'market', 'The', 'total', 'cost', 'was', 'He', 'visited', 'the', 'market', 'on', 'For', 'any', 'queries', 'contact', 'him', 'at', 'john', 'doe', 'example', 'com', 'or', 'call', 'at', 'His', 'order', 'number', 'was', 'and', 'was', 'delivered', 'on', 'His', 'friend', 's', 'email', 'is', 'jane_smith', 'work', 'email', 'co', 'uk', 'and', 'her', 'phone', 'number', 'is']
# Numbers(18):['3', '2', '5', '15', '75', '05', '07', '2024', '123', '456', '7890', '456123789', '10', '07', '2024', '987', '654', '3210']

# %% [markdown]
# จาก text_work1 ให้ค้นหาอีเมล

# %%
# Out:
# Emails found(2):['john.doe@example.com', 'jane_smith@work-email.co.uk']

# %% [markdown]
# จาก text_work1 ให้ค้นหาเบอร์โทร

# %%
# Out:
# Phone numbers found(2):['(123) 456-7890', '987-654-3210']

# %% [markdown]
# จาก text_work1 ให้ค้นหาวันที่

# %%
# Out:
# Dates found(len(['05/07/2024', '10-07-2024'])):['05/07/2024', '10-07-2024']

# %% [markdown]
# จาก text_work1 ให้ค้นหาตัวเลขที่ไม่ใช่ เบอร์โทร และ วันที่

# %%
# Out:
# Numbers found (excluding dates and phone numbers): ['3', '2', '5', '15', '75', '456123789']
